# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# ^STOXX50E
df = pd.read_csv('euro_stoxx50.csv')
df
# Out:
#            Price              Close               High                Low  \
# 0         Ticker          ^STOXX50E          ^STOXX50E          ^STOXX50E
# 1           Date                NaN                NaN                NaN
# 2     2015-01-05  3023.139892578125  3150.090087890625    3020.7900390625
# 3     2015-01-07    3026.7900390625    3055.8701171875  3002.780029296875
# 4     2015-01-08     3135.080078125     3139.919921875  3051.260009765625
# ...          ...                ...                ...                ...
# 2714  2025-10-16     5652.009765625   5652.10986328125    5585.9501953125
# 2715  2025-10-17   5607.39013671875   5640.56005859375            5555.25
# 2716  2025-10-20   5680.93017578125     5688.169921875            5626.25
# 2717  2025-10-21     5686.830078125    5699.1298828125   5670.64990234375
# 2718  2025-10-22    5639.2099609375    5685.2998046875   5635.89990234375
#
#                    Open     Volume
# 0             ^STOXX50E  ^STOXX50E
# ...

# %%
# Rename date column:
df.rename(columns={"Price": "Date"}, inplace=True)

# %%
df.drop([0, 1], axis=0, inplace=True)  # Delete rows with index 0 and 1.

# %%
df
# Out:
#             Date              Close               High                Low  \
# 2     2015-01-05  3023.139892578125  3150.090087890625    3020.7900390625
# 3     2015-01-07    3026.7900390625    3055.8701171875  3002.780029296875
# 4     2015-01-08     3135.080078125     3139.919921875  3051.260009765625
# 5     2015-01-09   3042.89990234375     3128.419921875   3021.22998046875
# 6     2015-01-12  3084.179931640625  3096.909912109375  3033.340087890625
# ...          ...                ...                ...                ...
# 2714  2025-10-16     5652.009765625   5652.10986328125    5585.9501953125
# 2715  2025-10-17   5607.39013671875   5640.56005859375            5555.25
# 2716  2025-10-20   5680.93017578125     5688.169921875            5626.25
# 2717  2025-10-21     5686.830078125    5699.1298828125   5670.64990234375
# 2718  2025-10-22    5639.2099609375    5685.2998046875   5635.89990234375
#
#                    Open     Volume
# 2      3126.81005859375   77456200
# ...

# %%
print(df.dtypes)
# Out:
# Date      object
# Close     object
# High      object
# Low       object
# Open      object
# Volume    object
# dtype: object

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%Y-%m-%d")

# %%
# Convert numeric columns
cols_numeric = ["Close", "High", "Low", "Open", "Volume"]
df[cols_numeric] = df[cols_numeric].apply(pd.to_numeric, errors="coerce")

# %%
print(df.dtypes)
# Out:
# Date      datetime64[ns]
# Close            float64
# High             float64
# Low              float64
# Open             float64
# Volume             int64
# dtype: object

# %%
plt.figure(figsize=(12, 6))
plt.plot(df["Date"], df["Close"], label="Close", color="blue")
plt.plot(df["Date"], df["Open"], label="Open", color="orange", alpha=0.6)
plt.title("EURO STOXX 50 - Temporal Series")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
